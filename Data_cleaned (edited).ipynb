# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'D:\de4e\Group Project\data_cleaned_2021.csv')
print(df.shape)
df.head()
# Out:
# (742, 42)
#    index                  Job Title              Salary Estimate  \
# 0      0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1      1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2      2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3      3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4      4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.dtypes
# Out:
# index                   int64
# Job Title              object
# Salary Estimate        object
# Job Description        object
# Rating                float64
# Company Name           object
# Location               object
# Headquarters           object
# Size                   object
# Founded                 int64
# Type of ownership      object
# Industry               object
# Sector                 object
# Revenue                object
# Competitors            object
# Hourly                  int64
# Employer provided       int64
# Lower Salary            int64
# Upper Salary            int64
# Avg Salary(K)         float64
# company_txt            object
# Job Location           object
# Age                     int64
# Python                  int64
# spark                   int64
# aws                     int64
# excel                   int64
# sql                     int64
# sas                     int64
# keras                   int64
# pytorch                 int64
# ...

# %%
df.shape
# Out:
# (742, 42)

# %%
df.nunique()
# Out:
# index                 742
# Job Title             264
# Salary Estimate       416
# Job Description       463
# Rating                 31
# Company Name          343
# Location              200
# Headquarters          198
# Size                    8
# Founded               102
# Type of ownership       9
# Industry               60
# Sector                 25
# Revenue                13
# Competitors           128
# Hourly                  2
# Employer provided       2
# Lower Salary          113
# Upper Salary          162
# Avg Salary(K)         219
# company_txt           343
# Job Location           37
# Age                   102
# Python                  2
# spark                   2
# aws                     2
# excel                   2
# sql                     2
# sas                     2
# keras                   2
# pytorch                 2
# scikit                  2
# tensor                  2
# hadoop                  2
# tableau                 2
# ...

# %%
del df["index"]

# %%
df.duplicated().sum()
# Out:
# 275

# %%
df=df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# Job Title             0
# Salary Estimate       0
# Job Description       0
# Rating                0
# Company Name          0
# Location              0
# Headquarters          0
# Size                  0
# Founded               0
# Type of ownership     0
# Industry              0
# Sector                0
# Revenue               0
# Competitors           0
# Hourly                0
# Employer provided     0
# Lower Salary          0
# Upper Salary          0
# Avg Salary(K)         0
# company_txt           0
# Job Location          0
# Age                   0
# Python                0
# spark                 0
# aws                   0
# excel                 0
# sql                   0
# sas                   0
# keras                 0
# pytorch               0
# scikit                0
# tensor                0
# hadoop                0
# tableau               0
# bi                    0
# flink                 0
# mongo                 0
# google_an             0
# ...

# %%
df[["Company Name", "company_txt"]].head()
# Out:
#                                  Company Name  \
# 0                      Tecolote Research\n3.8
# 1  University of Maryland Medical System\n3.4
# 2                                KnowBe4\n4.8
# 3                                   PNNL\n3.8
# 4                     Affinity Solutions\n2.9
#
#                              company_txt
# 0                      Tecolote Research
# 1  University of Maryland Medical System
# 2                                KnowBe4
# 3                                   PNNL
# 4                     Affinity Solutions

# %%
df["Company Name"] = df["company_txt"]

# %%
df=df.drop(columns={'company_txt','Age','Headquarters'})

# %%
df = df.rename(columns={"job_title_sim":"Title Cat", "seniority_by_title":"Seniority","Job Location":"State"})

# %%
df["Rating"]=df["Rating"].astype(str).str.replace("-1", "1").astype(float)
df["Founded"]=df["Founded"].astype(str).str.replace("-1", "Unknown")
df["Industry"]=df["Industry"].astype(str).str.replace("-1", "Unknown")
df["Sector"]=df["Sector"].astype(str).str.replace("-1", "Unknown")
df["Competitors"]=df["Competitors"].astype(str).str.replace("-1", "None")
df["Degree"]=df["Degree"].str.replace("na", "B")
df["Hourly"]=df["Hourly"].astype(str).str.replace("0", "Fulltime").str.replace("1","Parttime")
df[["Rating", "Founded", "Industry", "Sector", "Competitors", "Degree", "Hourly", "Title Cat", "Seniority", "State"]]
# Out:
#      Rating  Founded                                 Industry  \
# 0       3.8     1973                      Aerospace & Defense
# 1       3.4     1984         Health Care Services & Hospitals
# 2       4.8     2010                        Security Services
# 3       3.8     1965                                   Energy
# 4       2.9     1998                  Advertising & Marketing
# ..      ...      ...                                      ...
# 695     4.3     1999  Enterprise Software & Network Solutions
# 700     3.4  Unknown                              IT Services
# 716     4.0     2006                Biotech & Pharmaceuticals
# 732     4.1     2007                      KUnknown2 Education
# 735     3.9     2011                                 Internet
#
#                            Sector  \
# 0             Aerospace & Defense
# 1                     Health Care
# 2               Business Services
# 3    Oil, Gas, Energy & Utilities
# 4               Business Services
# ...

# %%
def rank_rating(rate):
    if rate >= 1 and rate < 2:
        return "bad"
    elif rate >= 2 and rate < 3:
        return "normal"
    elif rate >= 3 and rate < 4:
        return "good"
    elif rate >= 4:
        return "great"

df["Rank"] = df["Rating"].apply(rank_rating)
df[["Rating", "Rank"]]
# Out:
#      Rating    Rank
# 0       3.8    good
# 1       3.4    good
# 2       4.8   great
# 3       3.8    good
# 4       2.9  normal
# ..      ...     ...
# 695     4.3   great
# 700     3.4    good
# 716     4.0   great
# 732     4.1   great
# 735     3.9    good
#
# [467 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df.shape)
df.head()
# Out:
# (467, 39)
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location          Size  \
# 0                      Tecolote Research  Albuquerque, NM   501 - 1000
# 1  University of Maryland Medical System    Linthicum, MD       10000+
# ...

# %%
df.to_csv(r'D:\DS_salaries_cleaned.csv', index = True)
